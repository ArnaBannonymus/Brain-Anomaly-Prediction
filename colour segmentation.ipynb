# %%
import cv2
img = cv2.imread('out3.png',0)
hsv_im=cv2.CASCADE_SCALE_IMAGE(img)
#hsv_im = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-6b273b7688ef> in <module>()
#       1 import cv2
#       2 img = cv2.imread('out3.png',0)
# ----> 3 hsv_im=cv2.CASCADE_SCALE_IMAGE(img)
#       4 #hsv_im = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#
# TypeError: 'int' object is not callable

# %%
from PIL import Image
im = Image.open('output.png')
for pixel in im.getdata():
    if pixel == (128,0,0):
        print ("Red coloured pixel")
    else:
        pixel = [0, 0, 0]
# Out:
# Red coloured pixel
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-55030d43adb1> in <module>()
#       3 for pixel in im.getdata():
#       4     if pixel == (128,0,0):
# ----> 5         print ("Red coloured pixel").count()
#       6     else:
#       7         pixel = [0, 0, 0]
#
# AttributeError: 'NoneType' object has no attribute 'count'

# %%
from PIL import Image

imagePath = 'output.png'
newImagePath = 'out4.png'
im = Image.open(imagePath)

def redOrBlack (im):
    newimdata = []
    redcolor = (255,0,0)
    blackcolor = (0,0,0)
    for color in im.getdata():
        if color == redcolor:
            newimdata.append( redcolor )
        else:
            newimdata.append( blackcolor )
    newim = Image.new(im.mode,im.size)
    newim.putdata(newimdata)
    return newim

redOrBlack(im).save(newImagePath)

# %%
import numpy as np
import cv2
 
im = cv2.imread('output.png')
#set color to a set of pixels
im[np.where((im == [128,0,0]).all(axis = 2))] = [0,0,0]
cv2.imwrite('out4.png', im)
# Out:
# True

# %%
import cv2 
 
im_gray = cv2.imread("brain.tif", cv2.IMREAD_GRAYSCALE)
im_color = cv2.applyColorMap(im_gray, cv2.COLORMAP_HSV)

# %%
im_color
cv2.imwrite('colourHSV.png', im_color)
# Out:
# True

# %%
from numpy import array
from scipy.misc import toimage
img=toimage(im_color)
img
# Out:
# C:\Users\Bipasha Roy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <PIL.Image.Image image mode=RGB size=256x255 at 0x177055A59E8>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('output.png', -1)
#cv2.imshow('GoldenGate',img)

color = ('b','g','r')
for channel,col in enumerate(color):
    histr = cv2.calcHist([img],[channel],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.title('Histogram for color scale picture')
plt.show()

while True:
    k = cv2.waitKey(0) & 0xFF     
    if k == 27: break             # ESC key to exit 
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6cc73df03cc5> in <module>()
#      15
#      16 while True:
# ---> 17     k = cv2.waitKey(0) & 0xFF
#      18     if k == 27: break             # ESC key to exit
#      19 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import operator

img = cv2.imread('output.png', -1)
cv2.imshow('Imagem:',img)

color = ('b','g','r')
qtdBlue = 0
qtdGreen = 0
qtdRed = 0
totalPixels = 0

for channel,col in enumerate(color):
    histr = cv2.calcHist([img],[channel],None,[256],[1,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
    totalPixels+=sum(histr)
    print (histr)
    if channel==0:
        qtdBlue = sum(histr)
    elif channel==1:
        qtdGreen = sum(histr)
    elif channel==2:
        qtdRed = sum(histr)

qtdBlue = (qtdBlue/totalPixels)*100
qtdGreen = (qtdGreen/totalPixels)*100
qtdRed = (qtdRed/totalPixels)*100

#qtdBlue = filter(operator.isNumberType, qtdBlue)
#qtdGreen = filter(operator.isNumberType, qtdGreen)
#qtdRed = filter(operator.isNumberType, qtdRed)

plt.title("Red: "+str(qtdRed)+"%; Green: "+str(qtdGreen)+"%; Blue: "+str(qtdBlue)+"%")
plt.show()
