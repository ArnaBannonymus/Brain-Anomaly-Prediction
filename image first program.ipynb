# %%
from PIL import Image
img=Image.open('download.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x187B31EF978>

# %%
import cv2
img=cv2.imread('download.jpg')

# %%
img
# Out:
# array([[[75, 75, 75],
#         [76, 76, 76],
#         [76, 76, 76],
#         ...,
#         [31, 31, 31],
#         [31, 31, 31],
#         [31, 31, 31]],
#
#        [[78, 78, 78],
#         [78, 78, 78],
#         [78, 78, 78],
#         ...,
#         [31, 31, 31],
#         [31, 31, 31],
#         [31, 31, 31]],
#
#        [[82, 82, 82],
#         [82, 82, 82],
#         [83, 83, 83],
#         ...,
#         [32, 32, 32],
#         [31, 31, 31],
#         [31, 31, 31]],
#
#        ...,
#
#        [[38, 38, 38],
#         [38, 38, 38],
#         [38, 38, 38],
#         ...,
#         [29, 29, 29],
#         [29, 29, 29],
#         [29, 29, 29]],
#
#        [[37, 37, 37],
#         [37, 37, 37],
#         [37, 37, 37],
#         ...,
#         [29, 29, 29],
#         [29, 29, 29],
#         [29, 29, 29]],
#
#        [[36, 36, 36],
#         [36, 36, 36],
#         [36, 36, 36],
#         ...,
#         [29, 29, 29],
#         [29, 29, 29],
#         [29, 29, 29]]], dtype=uint8)

# %%
from numpy import array
from scipy.misc import toimage
image=toimage(img)
# Out:
# C:\Users\Bipasha Roy\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x187B4AEA5C0>

# %%
h,w=image.size

# %%
h
# Out:
# 275

# %%
w
# Out:
# 183

# %%
h*w
# Out:
# 50325

# %%
pixel[1,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8ed9d703e6f5> in <module>()
# ----> 1 pixel[1,2]
#
# NameError: name 'pixel' is not defined
